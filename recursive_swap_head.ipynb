# %%
from typing import Optional

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def swapPairs(head: Optional[ListNode]) -> Optional[ListNode]:
    # Base Case
    if not head or not head.next:
        return head
    # Store the next node in the list
    next_node = head.next
    # Swap the current node and the next node
    head.next = swapPairs(next_node.next)
    next_node.next = head
    # Return the new head of the modified list.
    return next_node

# %%
# Verbose Explaination of the above code
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def swap_pairs(head):
    # Base case: If the list is empty or has only one node, no swapping is needed.
    if not head or not head.next:
        print("# Base case: If the list is empty or has only one node, no swapping is needed.")
        return head

    # Store the next node in the list.
    print("# Store the next node in the list.")
    try:
        print("current head.val",head.val)
    except AttributeError:
        print("stored: head.val is NoneType")
    print("next_node = head.next")
    next_node = head.next
    try:
        print("stored: next_node.val", next_node.val)
    except AttributeError:
        print("stored: next_node.val is NoneType")

    # Swap the current node and the next node.
    print("# Swap the current node and the next node.")
    print("head.next = swap_pairs(next_node.next)")
    try:
        print("sent next_node.next", next_node.next.val)
    except AttributeError:
        print("sent: next_node.next.val is NoneType")
    head.next = swap_pairs(next_node.next)
    try:
        print("assigned head.next", head.next.val)
    except AttributeError:
        print("stored: head.next.val is NoneType")
        print("head is {}".format(head.val))
    print("next_node.next = head")
    next_node.next = head
    try:
        print("new next_node.next.val: {} gets head: {}".format(next_node.next.val, head.val))
    except AttributeError:
        print("Attribute errore when calling next_node.next.val, head.val")

    # Return the new head of the modified list.
    print("# Return the new head of the modified list.")
    print("return next_node")
    try:
        print("returning next_node.val", next_node.val)
    except AttributeError:
        print("stored: next_node.val is NoneType")
    return next_node

# Helper function to print the linked list.
def print_linked_list(head):
    current = head
    while current:
        print(current.val, end=" -> ")
        current = current.next
    print("None")

# Example usage:
if __name__ == "__main__":
    # Create a sample linked list: 1 -> 2 -> 3 -> 4
    head = ListNode(1, ListNode(2, ListNode(3, ListNode(4))))
    
    print("Original Linked List:")
    print_linked_list(head)

    # Swap every two adjacent nodes recursively.
    new_head = swap_pairs(head)

    print("Linked List after Swapping Pairs:")
    print_linked_list(new_head)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 4 -> None
# # Store the next node in the list.
# current head.val 1
# next_node = head.next
# stored: next_node.val 2
# # Swap the current node and the next node.
# head.next = swap_pairs(next_node.next)
# sent next_node.next 3
# # Store the next node in the list.
# current head.val 3
# next_node = head.next
# stored: next_node.val 4
# # Swap the current node and the next node.
# head.next = swap_pairs(next_node.next)
# sent: next_node.next.val is NoneType
# # Base case: If the list is empty or has only one node, no swapping is needed.
# stored: head.next.val is NoneType
# head is 3
# next_node.next = head
# new next_node.next.val: 3 gets head: 3
# # Return the new head of the modified list.
# return next_node
# returning next_node.val 4
# assigned head.next 4
# next_node.next = head
# new next_node.next.val: 1 gets head: 1
# # Return the new head of the modified list.
# return next_node
# returning next_node.val 2
# ...

# %%
# Helper function to print the linked list.
def print_linked_list(head):
    current = head
    while current:
        print(current.val, end=" -> ")
        current = current.next
    print("None")

# Example usage:
if __name__ == "__main__":
    # Create a sample linked list: 1 -> 2 -> 3 -> 4
    head = ListNode(1, ListNode(2, ListNode(3, ListNode(4))))
    
    print("Original Linked List:")
    print_linked_list(head)

    # Swap every two adjacent nodes recursively.
    new_head = swapPairs(head)

    print("Linked List after Swapping Pairs:")
    print_linked_list(new_head)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 4 -> None
# Linked List after Swapping Pairs:
# 2 -> 1 -> 4 -> 3 -> None
